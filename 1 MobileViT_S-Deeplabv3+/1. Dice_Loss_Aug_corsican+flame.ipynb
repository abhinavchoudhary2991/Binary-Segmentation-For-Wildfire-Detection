# %%
# !python model.py

# %%
Training: ALl BS did good

TESTING:
    
BS =4 

Accuracy: 0.99079
F1: 0.88371
Jaccard: 0.79926
Recall: 0.86732
Precision: 0.90934
Mean Pixel Accuracy: 0.99079
Matthews Correlation Coefficient: 0.87991
    
BS = 8

Accuracy: 0.99277
F1: 0.89343
Jaccard: 0.81357
Recall: 0.87247
Precision: 0.92319
Mean Pixel Accuracy: 0.99277
Matthews Correlation Coefficient: 0.89070
    
BS =16

Accuracy: 0.99299
F1: 0.89537
Jaccard: 0.81569
Recall: 0.89044
Precision: 0.90605
Mean Pixel Accuracy: 0.99299
Matthews Correlation Coefficient: 0.89213

# %%
#!pip install keras-applications

# %%
#!pip install -U tensorflow-addons

# %%
#!pip install nvidia-tensorrt

# %%
#!python data.py
# Out:
# /bin/bash: /home/safeg34/anaconda3/envs/tf/lib/libtinfo.so.6: no version information available (required by /bin/bash)
# Train:	 1603 - 1603
# Test:	 400 - 400
#   9%|███▌                                    | 143/1603 [00:24<03:50,  6.33it/s]

# %%
# !python model.py
# Out:
# /bin/bash: /home/safeg34/anaconda3/envs/tf/lib/libtinfo.so.6: no version information available (required by /bin/bash)
# 2023-06-23 21:27:46.030617: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 AVX512F AVX512_VNNI FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-06-23 21:27:46.168922: I tensorflow/core/util/util.cc:169] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2023-06-23 21:27:46.203461: E tensorflow/stream_executor/cuda/cuda_blas.cc:2981] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# ...

# %% [markdown]
# # TRIAL 1

# %% [markdown]
# TRIAL 1: DICE LOSS
# batch_size = 4
#     lr = 1e-4
#     num_epochs = 30
#
# Good results

# %%
# !python train.py
# Out:
# /bin/bash: /home/safeg34/anaconda3/envs/tf/lib/libtinfo.so.6: no version information available (required by /bin/bash)
# 2023-06-24 00:26:27.370244: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 AVX512F AVX512_VNNI FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-06-24 00:26:27.499087: I tensorflow/core/util/util.cc:169] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2023-06-24 00:26:27.529360: E tensorflow/stream_executor/cuda/cuda_blas.cc:2981] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# ...

# %%
# !python eval.py

Accuracy: 0.99079
F1: 0.88371
Jaccard: 0.79926
Recall: 0.86732
Precision: 0.90934
Mean Pixel Accuracy: 0.99079
Matthews Correlation Coefficient: 0.87991
# Out:
# /bin/bash: /home/safeg34/anaconda3/envs/tf/lib/libtinfo.so.6: no version information available (required by /bin/bash)
# 2023-06-24 09:52:50.264488: E tensorflow/stream_executor/cuda/cuda_blas.cc:2981] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# Test: 469 - 469
# ...
# 1/1 [==============================] - 4s 4s/step
# Mask dtype: int32
# y_pred dtype: int32
# 1/1 [==============================] - 0s 62ms/step
# Mask dtype: int32
# y_pred dtype: int32
# 1/1 [==============================] - 0s 52ms/step
# Mask dtype: int32
# y_pred dtype: int32
# 1/1 [==============================] - 0s 54ms/step
# Mask dtype: int32
# y_pred dtype: int32
# 1/1 [==============================] - 0s 60ms/step
# Mask dtype: int32
# y_pred dtype: int32
# 1/1 [==============================] - 0s 60ms/step
# Mask dtype: int32
# y_pred dtype: int32
# 1/1 [==============================] - 0s 59ms/step
# Mask dtype: int32
# ...

# %%
# !python predict.py
# Out:
# /bin/bash: /home/safeg34/anaconda3/envs/tf/lib/libtinfo.so.6: no version information available (required by /bin/bash)
# 2023-06-24 09:58:12.036748: E tensorflow/stream_executor/cuda/cuda_blas.cc:2981] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# ...
# 100%|███████████████████████████████████████████| 47/47 [00:23<00:00,  1.99it/s]

# %% [markdown]
# # TRIAL 2

# %% [markdown]
# TRIAL 3: DICE LOSS
#
# batch_size = 8
#     lr = 1e-4
#     num_epochs = 30

# %%
# !python train.py
# Out:
# /bin/bash: /home/safeg34/anaconda3/envs/tf/lib/libtinfo.so.6: no version information available (required by /bin/bash)
# 2023-06-24 13:59:51.972655: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 AVX512F AVX512_VNNI FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-06-24 13:59:52.123536: I tensorflow/core/util/util.cc:169] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2023-06-24 13:59:52.153299: E tensorflow/stream_executor/cuda/cuda_blas.cc:2981] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# ...

# %%
# !python eval.py

Accuracy: 0.99277
F1: 0.89343
Jaccard: 0.81357
Recall: 0.87247
Precision: 0.92319
Mean Pixel Accuracy: 0.99277
Matthews Correlation Coefficient: 0.89070
# Out:
# /bin/bash: /home/safeg34/anaconda3/envs/tf/lib/libtinfo.so.6: no version information available (required by /bin/bash)
# 2023-06-24 16:55:34.798322: E tensorflow/stream_executor/cuda/cuda_blas.cc:2981] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# Test: 469 - 469
# ...
# 1/1 [==============================] - 4s 4s/step
# Mask dtype: int32
# y_pred dtype: int32
# 1/1 [==============================] - 0s 66ms/step
# Mask dtype: int32
# y_pred dtype: int32
# 1/1 [==============================] - 0s 60ms/step
# Mask dtype: int32
# y_pred dtype: int32
# 1/1 [==============================] - 0s 64ms/step
# Mask dtype: int32
# y_pred dtype: int32
# 1/1 [==============================] - 0s 66ms/step
# Mask dtype: int32
# y_pred dtype: int32
# 1/1 [==============================] - 0s 62ms/step
# Mask dtype: int32
# y_pred dtype: int32
# 1/1 [==============================] - 0s 62ms/step
# Mask dtype: int32
# ...

# %%
# !python predict.py
# Out:
# /bin/bash: /home/safeg34/anaconda3/envs/tf/lib/libtinfo.so.6: no version information available (required by /bin/bash)
# 2023-06-24 17:04:40.660579: E tensorflow/stream_executor/cuda/cuda_blas.cc:2981] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# ...
# 100%|███████████████████████████████████████████| 47/47 [00:24<00:00,  1.92it/s]

# %% [markdown]
# # TRIAL 3

# %% [markdown]
# TRIAL 3: DICE LOSS
#
# batch_size = 16
#     lr = 1e-4
#     num_epochs = 30
#
# Results: Good, at par with BS =4

# %%
# !python train.py
# Out:
# /bin/bash: /home/safeg34/anaconda3/envs/tf/lib/libtinfo.so.6: no version information available (required by /bin/bash)
# 2023-06-24 10:06:22.820121: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 AVX512F AVX512_VNNI FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-06-24 10:06:22.967813: I tensorflow/core/util/util.cc:169] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2023-06-24 10:06:22.997925: E tensorflow/stream_executor/cuda/cuda_blas.cc:2981] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# ...

# %%
# !python eval.py

Accuracy: 0.99299
F1: 0.89537
Jaccard: 0.81569
Recall: 0.89044
Precision: 0.90605
Mean Pixel Accuracy: 0.99299
Matthews Correlation Coefficient: 0.89213
# Out:
# /bin/bash: /home/safeg34/anaconda3/envs/tf/lib/libtinfo.so.6: no version information available (required by /bin/bash)
# 2023-06-24 13:15:46.934237: E tensorflow/stream_executor/cuda/cuda_blas.cc:2981] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# Test: 469 - 469
# ...
# 1/1 [==============================] - 4s 4s/step
# Mask dtype: int32
# y_pred dtype: int32
# 1/1 [==============================] - 0s 63ms/step
# Mask dtype: int32
# y_pred dtype: int32
# 1/1 [==============================] - 0s 57ms/step
# Mask dtype: int32
# y_pred dtype: int32
# 1/1 [==============================] - 0s 59ms/step
# Mask dtype: int32
# y_pred dtype: int32
# 1/1 [==============================] - 0s 55ms/step
# Mask dtype: int32
# y_pred dtype: int32
# 1/1 [==============================] - 0s 59ms/step
# Mask dtype: int32
# y_pred dtype: int32
# 1/1 [==============================] - 0s 59ms/step
# Mask dtype: int32
# ...

# %%
# !python predict.py
# Out:
# /bin/bash: /home/safeg34/anaconda3/envs/tf/lib/libtinfo.so.6: no version information available (required by /bin/bash)
# 2023-06-24 13:56:36.429695: E tensorflow/stream_executor/cuda/cuda_blas.cc:2981] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# ...
# 100%|███████████████████████████████████████████| 47/47 [00:23<00:00,  1.98it/s]
